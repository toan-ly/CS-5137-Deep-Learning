# %%
# !curl -LsSf https://astral.sh/uv/install.sh | bash
# %cd /content/
# %rm -rf CS-5137-Deep-Learning

# !git clone https://github.com/toan-ly/CS-5137-Deep-Learning
# %cd CS-5137-Deep-Learning
# !uv sync
# Out:
# downloading uv 0.9.8 x86_64-unknown-linux-gnu
# no checksums to verify
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!
# /content
# Cloning into 'CS-5137-Deep-Learning'...
# remote: Enumerating objects: 1747, done.
# remote: Counting objects: 100% (135/135), done.
# remote: Compressing objects: 100% (120/120), done.
# remote: Total 1747 (delta 26), reused 117 (delta 15), pack-reused 1612 (from 2)
# Receiving objects: 100% (1747/1747), 314.18 MiB | 41.75 MiB/s, done.
# Resolving deltas: 100% (610/610), done.
# /content/CS-5137-Deep-Learning
# Using CPython 3.11.14
# Creating virtual environment at: .venv
# Resolved 87 packages in 1ms
# Prepared 4 packages in 356ms
# Installed 81 packages in 433ms
#  + asttokens==3.0.0
#  + comm==0.2.3
#  + contourpy==1.3.3
#  + cycler==0.12.1
#  + debugpy==1.8.17
#  + decorator==5.2.1
#  + executing==2.2.1
#  + filelock==3.19.1
#  + fonttools==4.59.2
#  + fsspec==2025.9.0
#  + imageio==2.37.2
#  + ipykernel==6.30.1
#  + ipython==9.6.0
#  + ipython-pygments-lexers==1.1.1
#  + jedi==0.19.2
#  + jinja2==3.1.6
#  + joblib==1.5.2
#  + jupyter-client==8.6.3
#  + jupyter-core==5.8.1
#  + kiwisolver==1.4.9
#  + lazy-loader==0.4
#  + markupsafe==3.0.2
#  + matplotlib==3.10.6
#  + matplotlib-inline==0.1.7
#  + missingno==0.5.2
#  + monai==1.5.1
#  + mpmath==1.3.0
#  + nest-asyncio==1.6.0
#  + networkx==3.5
#  + numpy==2.2.6
#  + nvidia-cublas-cu12==12.8.4.1
#  + nvidia-cuda-cupti-cu12==12.8.90
#  + nvidia-cuda-nvrtc-cu12==12.8.93
#  + nvidia-cuda-runtime-cu12==12.8.90
#  + nvidia-cudnn-cu12==9.10.2.21
#  + nvidia-cufft-cu12==11.3.3.83
#  + nvidia-cufile-cu12==1.13.1.3
#  + nvidia-curand-cu12==10.3.9.90
#  + nvidia-cusolver-cu12==11.7.3.90
#  + nvidia-cusparse-cu12==12.5.8.93
#  + nvidia-cusparselt-cu12==0.7.1
#  + nvidia-nccl-cu12==2.27.3
#  + nvidia-nvjitlink-cu12==12.8.93
#  + nvidia-nvtx-cu12==12.8.90
#  + opencv-python-headless==4.12.0.88
#  + packaging==25.0
#  + pandas==2.3.2
#  + parso==0.8.5
#  + pexpect==4.9.0
#  + pillow==11.3.0
#  + platformdirs==4.5.0
#  + prompt-toolkit==3.0.52
#  + psutil==7.1.0
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pygments==2.19.2
#  + pyparsing==3.2.3
#  + python-dateutil==2.9.0.post0
#  + pytz==2025.2
#  + pyyaml==6.0.3
#  + pyzmq==27.1.0
#  + scikit-image==0.25.2
#  + scikit-learn==1.7.2
#  + scipy==1.16.1
#  + seaborn==0.13.2
#  + setuptools==80.9.0
#  + six==1.17.0
#  + stack-data==0.6.3
#  + sympy==1.14.0
#  + sync==1.0.0
#  + threadpoolctl==3.6.0
#  + tifffile==2025.10.16
#  + torch==2.8.0
#  + torchvision==0.23.0
#  + tornado==6.5.2
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + triton==3.4.0
#  + typing-extensions==4.15.0
#  + tzdata==2025.2
#  + wcwidth==0.2.14

# %%
# %cd /content/CS-5137-Deep-Learning/homework3/
# !uv run -m src.train --config configs/train.yaml \
    --data_root ./data \
    --batch_size 12 --lr 1e-3 --patch_size 128 \
    --base_channels 64 --depth 3 --up_mode nearest --block_type base --norm_type batch \
    --save_dir checkpoints/norm --save_plots_path results/predictions/norm
# Out:
# /content/CS-5137-Deep-Learning/homework3
# Loading dataset: 100% 64/64 [00:01<00:00, 45.59it/s]
# Loading dataset: 100% 16/16 [00:00<00:00, 48.53it/s]
# Image batch shape: torch.Size([96, 4, 128, 128])
# Mask batch shape: torch.Size([96, 1, 128, 128])
#
# Image batch shape: torch.Size([12, 4, 512, 512])
# Mask batch shape: torch.Size([12, 1, 512, 512])
#
# Model summary:
# UNet(
#   (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#   (encoder): ModuleList(
#     (0): DownBlock(
#       (double_conv): DoubleConv(
#         (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         (double_conv): Sequential(
#           (0): Conv2d(4, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): LeakyReLU(negative_slope=0.1, inplace=True)
#           (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (1): DownBlock(
#       (double_conv): DoubleConv(
#         (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         (double_conv): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): LeakyReLU(negative_slope=0.1, inplace=True)
#           (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (2): DownBlock(
#       (double_conv): DoubleConv(
#         (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         (double_conv): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): LeakyReLU(negative_slope=0.1, inplace=True)
#           (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (bottleneck): DoubleConv(
#     (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     (double_conv): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1, inplace=True)
#       (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#   )
#   (bridge_dropout): Dropout2d(p=0.5, inplace=False)
#   (decoder): ModuleList(
#     (0): UpBlock(
#       (up_conv): Sequential(
#         (0): Upsample(scale_factor=2.0, mode='nearest')
#         (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (double_conv): DoubleConv(
#         (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         (double_conv): Sequential(
#           (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): LeakyReLU(negative_slope=0.1, inplace=True)
#           (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#     )
#     (1): UpBlock(
#       (up_conv): Sequential(
#         (0): Upsample(scale_factor=2.0, mode='nearest')
#         (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (double_conv): DoubleConv(
#         (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         (double_conv): Sequential(
#           (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): LeakyReLU(negative_slope=0.1, inplace=True)
#           (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#     )
#     (2): UpBlock(
#       (up_conv): Sequential(
#         (0): Upsample(scale_factor=2.0, mode='nearest')
#         (1): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (double_conv): DoubleConv(
#         (act): LeakyReLU(negative_slope=0.1, inplace=True)
#         (double_conv): Sequential(
#           (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): LeakyReLU(negative_slope=0.1, inplace=True)
#           (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#     )
#   )
#   (final_conv): FinalOutput(
#     (conv): Conv2d(64, 3, kernel_size=(1, 1), stride=(1, 1))
#   )
# )
# Number of trainable parameters: 7187587
#
# Starting training at: 20251108-231431
#
# Epoch 5/200 - Train Loss: 12.6629, Train Dice: 0.7060, Train IoU: 0.5579 | Val Loss: 1.8986, Val Dice: 0.1505, Val IoU: 0.0823
# Epoch 10/200 - Train Loss: 11.4273, Train Dice: 0.7405, Train IoU: 0.5972 | Val Loss: 1.5204, Val Dice: 0.7008, Val IoU: 0.5412
# Epoch 15/200 - Train Loss: 10.5264, Train Dice: 0.7554, Train IoU: 0.6171 | Val Loss: 1.1991, Val Dice: 0.7662, Val IoU: 0.6228
# Epoch 20/200 - Train Loss: 10.4463, Train Dice: 0.7675, Train IoU: 0.6294 | Val Loss: 1.1596, Val Dice: 0.7798, Val IoU: 0.6406
# Epoch 25/200 - Train Loss: 10.0792, Train Dice: 0.7817, Train IoU: 0.6487 | Val Loss: 1.0837, Val Dice: 0.7818, Val IoU: 0.6432
# Epoch 30/200 - Train Loss: 9.7518, Train Dice: 0.7880, Train IoU: 0.6561 | Val Loss: 1.0310, Val Dice: 0.7969, Val IoU: 0.6637
# Epoch 35/200 - Train Loss: 9.6482, Train Dice: 0.7969, Train IoU: 0.6688 | Val Loss: 1.0331, Val Dice: 0.7971, Val IoU: 0.6639
# Epoch 40/200 - Train Loss: 9.7563, Train Dice: 0.7933, Train IoU: 0.6647 | Val Loss: 1.0656, Val Dice: 0.8046, Val IoU: 0.6742
# Epoch 45/200 - Train Loss: 9.4016, Train Dice: 0.7915, Train IoU: 0.6627 | Val Loss: 0.9902, Val Dice: 0.8105, Val IoU: 0.6826
# Epoch 50/200 - Train Loss: 9.3386, Train Dice: 0.8020, Train IoU: 0.6759 | Val Loss: 0.9825, Val Dice: 0.8073, Val IoU: 0.6784
# Epoch 55/200 - Train Loss: 9.3910, Train Dice: 0.7985, Train IoU: 0.6699 | Val Loss: 0.9639, Val Dice: 0.8172, Val IoU: 0.6918
# Epoch 60/200 - Train Loss: 9.2924, Train Dice: 0.8042, Train IoU: 0.6781 | Val Loss: 0.9831, Val Dice: 0.8112, Val IoU: 0.6834
# Epoch 65/200 - Train Loss: 9.3382, Train Dice: 0.8079, Train IoU: 0.6829 | Val Loss: 0.9683, Val Dice: 0.8127, Val IoU: 0.6855
# Epoch 70/200 - Train Loss: 9.1637, Train Dice: 0.8060, Train IoU: 0.6809 | Val Loss: 0.9597, Val Dice: 0.8132, Val IoU: 0.6862
# Epoch 75/200 - Train Loss: 9.2806, Train Dice: 0.8076, Train IoU: 0.6836 | Val Loss: 0.9483, Val Dice: 0.8163, Val IoU: 0.6907
# Epoch 80/200 - Train Loss: 9.2342, Train Dice: 0.8080, Train IoU: 0.6843 | Val Loss: 0.9642, Val Dice: 0.8171, Val IoU: 0.6918
# Epoch 85/200 - Train Loss: 9.2106, Train Dice: 0.8084, Train IoU: 0.6838 | Val Loss: 0.9464, Val Dice: 0.8189, Val IoU: 0.6943
# => Early stopping at epoch 86
# Training time: 1011.58s | (best val dice = 0.8203)
# Model saved to checkpoints/norm/best_model.pth
# Training completed at: 20251108-231431

# %%
# %cd /content/CS-5137-Deep-Learning/homework3/
# !uv run -m src.train --config configs/train.yaml \
#     --data_root ./data \
#     --batch_size 8 --lr 1e-3 --patch_size 128 \
#     --base_channels 64 --depth 4 --up_mode transpose --block_type base \
#     --save_dir checkpoints/no_norm --save_plots_path results/predictions/no_norm

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

def plot_loss(loss_df, save_dir):
    legend_loc = 'lower right'
    fig, axs = plt.subplots(1, 3, figsize=(12, 4))
    axs[0].plot(loss_df['epoch'], loss_df['train_loss'], label='train_loss')
    axs[0].plot(loss_df['epoch'], loss_df['val_loss'], label='val_loss')
    axs[0].set_xlabel('Epoch')
    axs[0].set_ylabel('Loss')
    axs[0].set_title('Training and Validation Loss')
    axs[0].legend(loc=legend_loc)

    axs[1].plot(loss_df['epoch'], loss_df['train_dice'], label='train_dice')
    axs[1].plot(loss_df['epoch'], loss_df['val_dice'], label='val_dice')
    axs[1].set_xlabel('Epoch')
    axs[1].set_ylabel('Dice')
    axs[1].set_title('Training and Validation Dice')
    axs[1].legend(loc=legend_loc)

    axs[2].plot(loss_df['epoch'], loss_df['train_iou'], label='train_iou')
    axs[2].plot(loss_df['epoch'], loss_df['val_iou'], label='val_iou')
    axs[2].set_xlabel('Epoch')
    axs[2].set_ylabel('IoU')
    axs[2].set_title('Training and Validation IoU')
    axs[2].legend(loc=legend_loc)

    plt.tight_layout()

    # os.makedirs(save_dir, exist_ok=True)
    plt.savefig(os.path.join(save_dir, 'train_curve.png'))
    plt.show()

# %%
# %cd /content/CS-5137-Deep-Learning/homework3/
history_norm = pd.read_csv('checkpoints/norm/training_history.csv')
plot_loss(history_norm, 'results/predictions/norm')
# history_no_norm = pd.read_csv('checkpoints/no_norm/training_history.csv')
# plot_loss(history_no_norm, 'results/predictions/no_norm')
# Out:
# /content/CS-5137-Deep-Learning/homework3

# %% [markdown]
# # Download weights

# %%
from google.colab import files
# !zip -r checkpoints.zip checkpoints results
files.download('checkpoints.zip')
# Out:
# updating: checkpoints/ (stored 0%)
# updating: checkpoints/norm/ (stored 0%)
# updating: checkpoints/norm/training_history.csv (deflated 50%)
# updating: checkpoints/norm/best_model.pth (deflated 5%)
# updating: results/ (stored 0%)
# updating: results/predictions/ (stored 0%)
# updating: results/predictions/norm/ (stored 0%)
# updating: results/predictions/norm/epoch_5.png (deflated 4%)
# updating: results/predictions/norm/epoch_35.png (deflated 5%)
# updating: results/predictions/norm/epoch_15.png (deflated 5%)
# updating: results/predictions/norm/epoch_40.png (deflated 5%)
# updating: results/predictions/norm/epoch_45.png (deflated 4%)
# updating: results/predictions/norm/epoch_25.png (deflated 5%)
# updating: results/predictions/norm/epoch_85.png (deflated 4%)
# updating: results/predictions/norm/epoch_55.png (deflated 4%)
# updating: results/predictions/norm/epoch_65.png (deflated 4%)
# updating: results/predictions/norm/epoch_50.png (deflated 4%)
# updating: results/predictions/norm/epoch_10.png (deflated 5%)
# updating: results/predictions/norm/train_curve.png (deflated 7%)
# updating: results/predictions/norm/epoch_80.png (deflated 4%)
# updating: results/predictions/norm/epoch_30.png (deflated 4%)
# updating: results/predictions/norm/epoch_75.png (deflated 4%)
# updating: results/predictions/norm/epoch_70.png (deflated 4%)
# updating: results/predictions/norm/epoch_60.png (deflated 4%)
# updating: results/predictions/norm/epoch_20.png (deflated 4%)
